# %%
import rosbag_pandas
import pandas as pd

df = rosbag_pandas.bag_to_dataframe("/tmp/fix3.bag")

# %%
import matplotlib.pyplot as plt
plt.figure()
df_diff = df["/adis16448bmlz/imu_micro/number"].dropna().astype(int).diff()
df_diff.plot()
df_diff[df_diff > 1].count() / df_diff.count().astype(float)
# Out:
# 0.000614889792829439

# %%
# Out:
# 0.0012500488300324231
